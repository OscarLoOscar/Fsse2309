# %% [markdown]
# <a href="https://colab.research.google.com/github/OscarLoOscar/Fsse2309/blob/main/jobsDB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import bs4 as bs
import urllib.request

# %%
# 定義請求標頭
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}

# 創建請求對象，並添加標頭
req = urllib.request.Request('https://hk.jobsdb.com/java-jobs?salaryrange=0-30000&salarytype=monthly&sortmode=ListedDate', headers=headers)

# 發送請求並讀取響應
source = urllib.request.urlopen(req).read()

# 解析網頁內容
soup = bs.BeautifulSoup(source, 'lxml')

# 找到所有包含特定屬性的 <div> 標籤
divs = soup.find_all('div', {'data-search-sol-meta': True})

# 提取每個 <div> 中的超鏈接和數據屬性
for div in divs:
    job_link = div.find('a', {'data-automation': 'job-list-view-job-link'})
    job_title = div.find('a', {'data-automation': 'jobTitle'})
    job_company = div.find('a', {'data-automation': 'jobCompany'})
    job_location = div.find('a', {'data-automation': 'jobLocation'})

    if job_link and job_title and job_company and job_location:
        print(f"Job Link: https://hk.jobsdb.com{job_link.get('href')}")
        print(f"Job Title: {job_title.text.strip()}")
        print(f"Job Company: {job_company.text.strip()}")
        print(f"Job Location: {job_location.text.strip()}")
        print('-' * 80)
# Out:
# Job Link: https://hk.jobsdb.com/job/75916765?type=standard&ref=search-standalone
# Job Title: Solutions Consultant / Support
# Job Company: Kyocera Document Solutions Hong Kong Limited
# Job Location: Tsuen Wan District
# --------------------------------------------------------------------------------
# Job Link: https://hk.jobsdb.com/job/75916778?type=standard&ref=search-standalone
# Job Title: Part-time Project Technical Assistant (two posts)
# Job Company: The Hong Kong Polytechnic University
# Job Location: Hung Hom
# --------------------------------------------------------------------------------
# Job Link: https://hk.jobsdb.com/job/75203167?type=standout&ref=search-standalone
# Job Title: Analyst Programmer
# Job Company: EC Healthcare
# Job Location: Quarry Bay
# --------------------------------------------------------------------------------
# Job Link: https://hk.jobsdb.com/job/75915416?type=standout&ref=search-standalone
# Job Title: Analyst Programmer - With Client Server Experiences (VCO209/J45)
# Job Company: VTECH Corporate Services Ltd
# Job Location: Tai Po District
# --------------------------------------------------------------------------------
# Job Link: https://hk.jobsdb.com/job/75915221?type=standout&ref=search-standalone
# Job Title: Digital Developer
# Job Company: Collinson International (Hong Kong) Limited
# Job Location: Quarry Bay
# --------------------------------------------------------------------------------
# Job Link: https://hk.jobsdb.com/job/75914365?type=standout&ref=search-standalone
# Job Title: Product Developer at Levi Strauss (Hong Kong) Limited
# Job Company: Jobsdb - SmartHire
# Job Location: Kwun Tong District
# --------------------------------------------------------------------------------
# Job Link: https://hk.jobsdb.com/job/72907379?type=standout&ref=search-standalone
# Job Title: Junior System Engineer (Secondment Contract)
# Job Company: China Taiping Life Insurance (Hong Kong) Company Limited
# Job Location: North Point
# --------------------------------------------------------------------------------
# Job Link: https://hk.jobsdb.com/job/75914141?type=standout&ref=search-standalone
# Job Company: Keysoc Limited
# Job Location: Cheung Sha Wan
# --------------------------------------------------------------------------------
# Job Link: https://hk.jobsdb.com/job/75839496?type=standout&ref=search-standalone
# Job Title: Devops Engineer
# Job Company: Aurex Group Limited
# Job Location: Central and Western District
# --------------------------------------------------------------------------------
# Job Link: https://hk.jobsdb.com/job/75839375?type=standout&ref=search-standalone
# Job Title: Business System Analyst (Confidential)
# Job Company: Aurex Group Limited
# Job Location: Central and Western District
# --------------------------------------------------------------------------------
# Job Link: https://hk.jobsdb.com/job/75839364?type=standout&ref=search-standalone
# Job Title: Analyst Developer (C# / .NET)
# Job Company: Rise Associates Asia Limited
# Job Location: Hong Kong
# --------------------------------------------------------------------------------
# Job Link: https://hk.jobsdb.com/job/75839313?type=standout&ref=search-standalone
# Job Title: Senior/ Onsite Technician, Audiovisual system (perm.) - MNC (HKD 25-31K)
# Job Company: TalentQuest HR Limited
# Job Location: Central
# --------------------------------------------------------------------------------
# Job Link: https://hk.jobsdb.com/job/75839172?type=standout&ref=search-standalone
# Job Title: Backend Developer (Ruby on Rails / Node.js)
# Job Company: Keysoc Limited
# Job Location: Lai Chi Kok
# --------------------------------------------------------------------------------
# Job Link: https://hk.jobsdb.com/job/75839153?type=standard&ref=search-standalone
# Job Title: QA Tester(遊戲測試員) - Fresh graduates are welcome
# Job Company: Qookia Limited
# Job Location: Kwai Fong
# --------------------------------------------------------------------------------
# Job Link: https://hk.jobsdb.com/job/75839065?type=standout&ref=search-standalone
# Job Title: Quality Assurance Engineer - Mobile Apps & Websites
# Job Company: Keysoc Limited
# Job Location: Cheung Sha Wan
# --------------------------------------------------------------------------------
# Job Link: https://hk.jobsdb.com/job/75838957?type=standout&ref=search-standalone
# Job Title: Senior System Analyst - Insurtech
# Job Company: Aurex Group Limited
# Job Location: Central and Western District
# --------------------------------------------------------------------------------
# Job Link: https://hk.jobsdb.com/job/75836138?type=standout&ref=search-standalone
# Job Title: Consumer Interactive Summer Internship 2024  (Undergraduate students only)
# Job Company: TransUnion Limited
# Job Location: Tsim Sha Tsui
# --------------------------------------------------------------------------------
# Job Link: https://hk.jobsdb.com/job/75836023?type=standout&ref=search-standalone
# Job Title: Product Management Summer Internship 2024  (Undergraduate students Only)
# Job Company: TransUnion Limited
# Job Location: Tsim Sha Tsui
# --------------------------------------------------------------------------------
# Job Link: https://hk.jobsdb.com/job/75835921?type=standout&ref=search-standalone
# Job Title: IT Operation engineer (Application Support)
# Job Company: AT Global Services Limited
# Job Location: Wan Chai
# --------------------------------------------------------------------------------
# Job Link: https://hk.jobsdb.com/job/75835491?type=standout&ref=search-standalone
# Job Title: Programmer (Fresh Graduates Are Welcome ! )
# Job Company: HKT Enterprise Solutions
# Job Location: Kowloon Bay
# --------------------------------------------------------------------------------
